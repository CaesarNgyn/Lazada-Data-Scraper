# %% [markdown]
# Import libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# URL (link) - Lazada

# %%
# URL to scrape
URL = "https://www.lazada.vn/dien-thoai-di-dong/?page=1&spm=a2o4n.searchlist.cate_1.1.5bb94c9aoYhimf"

# %% [markdown]
# Define extracting functions

# %%
# Function to extract Product Title
def get_title(soup):
    
    try:
        # Find the <h1> tag with class "pdp-mod-product-badge-title"
        title = soup.find("h1", attrs={"class": "pdp-mod-product-badge-title"})
        
        # Extract the text from the <h1> tag
        title_value = title.text

        # Clean up the title text
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'notranslate pdp-price pdp-price_type_deleted pdp-price_color_lightgray pdp-price_size_xs'}).string.strip()
    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'class':'notranslate pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Brand Title
def get_brand(soup):

    try:
        # Find the <h1> tag with class "pdp-mod-product-badge-title"
        brand = soup.find("a", attrs={"class": "pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
        
        # Extract the text from the <h1> tag
        brand_value = brand.text

        # Clean up the title text
        brand_string = brand_value.strip()

    except AttributeError:
        brand_string = ""

    return brand_string

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("a", attrs={'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# %% [markdown]
# Extract products's informations and convert it into CSV file

# %%
# URL to scrape
URL = "https://www.lazada.vn/dien-thoai-di-dong/?page=1&spm=a2o4n.searchlist.cate_1.1.5bb94c9aoYhimf"

# Set up WebDriver
driver = webdriver.Chrome(ChromeDriverManager().install())

try:
    # Open the webpage
    driver.get(URL)

    # Optionally, wait for dynamic content to load
    driver.implicitly_wait(10)  # Wait for up to 10 seconds for elements to appear

    # Get the page source after JavaScript has rendered the page
    page_source = driver.page_source

    # Parse the page source with BeautifulSoup
    soup = BeautifulSoup(page_source, "html.parser")

    # Fetch all divs with class 'RfADt', class which contains product's detail link
    divs = soup.find_all("div", attrs={'class': 'RfADt'})

    # Extract <a> tags from each div
    links = []
    for div in divs:
        a_tags = div.find_all("a")
        for a in a_tags:
            href = a.get('href')
            if href:
                absolute_link = "https:" + href  # Lazada links are often relative, so add "https:" prefix
                links.append(absolute_link)

    # print(">>links:", links)
    
    #Specify the dictionary format
    d = {"title":[], "brand":[], "price":[], "reviews":[]}
    
    # If you have at least one link, process the first one
    for link in links:
        # Open the webpage of the first link
        driver.get(link)

        # Optionally, wait for dynamic content to load
        driver.implicitly_wait(10)  # Wait for up to 3 seconds for elements to appear

        # Get the page source after JavaScript has rendered the page
        page_source_detail = driver.page_source

        # Parse the page source with BeautifulSoup
        soup_detail = BeautifulSoup(page_source_detail, "html.parser")
    
        # Extract and store the product title
        d['title'].append(get_title(soup_detail))
        d['brand'].append(get_brand(soup_detail))
        d['price'].append(get_price(soup_detail))
        d['reviews'].append(get_review_count(soup_detail))

        lazada_df = pd.DataFrame.from_dict(d) #converting into data frame 
        lazada_df['title'].replace('', np.nan, inplace=True) #replace all empty value with NaN value
        lazada_df = lazada_df.dropna(subset=['title']) #remove empty title values 
        lazada_df.to_csv("lazada_data.csv", header=True, index=True) #convert into CSV file
finally:
    print("Scraping done!")
    # Close the browser
    driver.quit()
# Out:
# Scraping done!

# %%
lazada_df
# Out:
#                                                 title     brand         price  \
# 0   [Sale 15.08] Điện Thoại OPPO A58 (6GB/128GB) -...      OPPO   4.990.000 ₫
# 1   [GIÁ SỈ] Pin điện thoại 5 / 5S / 5C / 6 / 6S /...    Xiaomi     139.000 ₫
# 2   Điện thoại Tecno SPARK GO 2024 (4+4)GB/64GB - ...     TECNO   2.590.000 ₫
# 3           Điện Thoại Samsung Galaxy A05s (4GB/128GB   Samsung   3.999.000 ₫
# 4          Samsung Galaxy A54 5G 8GB/128GB Chính Hãng   Samsung   8.990.000 ₫
# 5   Điện thoại ZTE Blade A52 3GB l 64GB, Pin 5000m...       ZTE   2.490.000 ₫
# 6   [GIỮA THÁNG SALE TO TỪ 20H 14.08 ] iPhone 15 P...     Apple  25.990.000 ₫
# 7   phone-vn.com Điện Thoại Người Già Good X6  4G ...      Good     305.000 ₫
# 8   [Trả góp 0%] Apple iPhone 15 Pro Max 256GB Chí...     Apple  35.490.000 ₫
# 9   Điện Thoại ZTE Blade V50 Design | 18GB(8GB+10G...       ZTE   2.990.000 ₫
# 10  [Trả góp 0%] Apple iPhone 15 Pro 128GB Chính h...     Apple  29.490.000 ₫
# 11  Điện thoại Tecno POVA 5 (8+8)/128GB - MediaTek...     TECNO   4.490.000 ₫
# 12  [GIỮA THÁNG SALE TO TỪ 20H 14.08 ] iPhone 15 P...     Apple  34.999.000 ₫
# 13                iPhone 15 Pro 128GB Chính Hãng VN/A     Apple  35.990.000 ₫
# 14  Điện thoại Oscal Tiger 12 12GB 256GB - màn hìn...     OSCAL   4.590.000 ₫
# 15  Điện thoại Samsung Galaxy A05s - Hàng chính hã...   Samsung   3.990.000 ₫
# 16  Điện thoại Samsung Galaxy A05s 128GB Chính Hãn...   Samsung   3.990.000 ₫
# 17  Điện thoại Tecno POVA 5 (8+8)/256GB - MediaTek...     TECNO   5.290.000 ₫
# 18  Samsung Galaxy S23 5G Ram 8GB | 128GB - Màn hì...   Samsung  22.990.000 ₫
# 19                   Điện thoại Samsung Galaxy A55 5G   Samsung  10.990.100 ₫
# 20          Điện Thoại Samsung Galaxy A05 (4GB/128GB)   Samsung   3.490.000 ₫
# 21  Điện thoại Samsung Galaxy A15 (8GB-128GB)/(8GB...   Samsung   5.890.000 ₫
# 22        Apple iPhone 15 Pro 256GB Chính hãng (VN/A)     Apple  32.990.000 ₫
# 23  [GIỮA THÁNG SALE TO TỪ 20H 14.08 ] iPhone 13 -...     Apple  24.990.000 ₫
# 24  Điện Thoại Xiaomi Redmi Note 13 (6+128GB) - Hà...    Xiaomi   4.890.000 ₫
# 25  Điện thoại OPPO Reno11 F 5G Ram 8GB | 256GB Ch...      OPPO   9.500.000 ₫
# 26  Điện Thoại Itel S23 8GB(4GB+4GB) /128GB và 16G...      Itel   3.490.000 ₫
# 27  Điện thoại Samsung Galaxy S24 Plus 5G 12GB/256...   Samsung  26.990.000 ₫
# 28        Điện thoại cũ ss j330 ( J3 pro ) ram 2gb/16  No Brand     429.000 ₫
# 29  Điện Thoại 6s Blus bản Q-Tế cài game nặng và ứ...  No Brand   1.500.000 ₫
# 30  Điện thoại Samsung Galaxy A15 8GB | 128GB - Ch...   Samsung   4.990.000 ₫
# 31  [Trả góp 0%] Apple iPhone 15 Plus 128GB Chính ...     Apple  26.790.000 ₫
# 32                      Điện thoại Samsung Galaxy A15   Samsung   5.590.200 ₫
# 33         Điện thoại thông minh Xiaomi 14 (12+256GB)    Xiaomi  22.990.000 ₫
# 34                     Điện thoại Samsung Galaxy A05s   Samsung   3.989.700 ₫
# 35  Điện thoại thông minh POCO C65 | 6.74" HD+ 90H...    Xiaomi   3.590.000 ₫
# 36  [GIỮA THÁNG SALE TO TỪ 20H 14.08 ] iPhone 15 -...     Apple  22.990.000 ₫
# 37  Điện Thoại ZTE Blade V50 Design | 18GB(8GB+10G...       ZTE   3.290.000 ₫
# 38  [GIỮA THÁNG SALE TO TỪ 20H 14.08 ] iPhone 15 P...     Apple  31.999.000 ₫
# 39                    iPhone 13 128GB Chính Hãng VN/A     Apple  16.900.000 ₫
#
#               reviews
# 0       1132 đánh giá
# 1         31 đánh giá
# 2         15 đánh giá
# 3          5 đánh giá
# 4          4 đánh giá
# 5         12 đánh giá
# 6        324 đánh giá
# 7          1 đánh giá
# 8         11 đánh giá
# 9         17 đánh giá
# 10  Không có đánh giá
# 11       600 đánh giá
# 12      3691 đánh giá
# 13  Không có đánh giá
# 14  Không có đánh giá
# 15        43 đánh giá
# 16        10 đánh giá
# 17        67 đánh giá
# 18  Không có đánh giá
# 19         6 đánh giá
# 20        14 đánh giá
# 21        82 đánh giá
# 22  Không có đánh giá
# 23      1076 đánh giá
# 24       188 đánh giá
# 25         2 đánh giá
# 26        59 đánh giá
# 27  Không có đánh giá
# 28        58 đánh giá
# 29         3 đánh giá
# 30        27 đánh giá
# 31  Không có đánh giá
# 32  Không có đánh giá
# 33         4 đánh giá
# 34  Không có đánh giá
# 35      2953 đánh giá
# 36       330 đánh giá
# 37         2 đánh giá
# 38       426 đánh giá
# 39         6 đánh giá
